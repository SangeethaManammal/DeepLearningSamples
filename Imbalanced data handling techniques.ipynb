# %%
import pandas as pd

ds_original = pd.read_csv("C:\\Users\\My Book\\Desktop\\Github Projects\\DeepLearning\\archive\\WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
ds_original.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
ds_original.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
ds_original.shape
# Out:
# (7043, 21)

# %%
ds_original.drop('customerID', axis='columns',inplace = True)

# %%
ds_altered_totalcharges = ds_original[ds_original.TotalCharges != ' ']
ds_altered_totalcharges.shape
# Out:
# (7032, 20)

# %%
ds_altered_totalcharges.TotalCharges = pd.to_numeric(ds_altered_totalcharges.TotalCharges,errors='coerce')
ds_altered_totalcharges.TotalCharges.dtypes
# Out:
# C:\Users\My Book\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# dtype('float64')

# %%
ds_altered_totalcharges.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
ds_altered_totalcharges.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
def print_column_values(df):
    for column in df:
        if(df[column].dtype == 'object'):
            print(f'{column} : {df[column].unique()}')

# %%
print_column_values(ds_altered_totalcharges)
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %%
ds_altered_totalcharges.replace('No phone service','No',inplace=True)
ds_altered_totalcharges.replace('No internet service','No',inplace=True)
print_column_values(ds_altered_totalcharges)
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes']
# OnlineBackup : ['Yes' 'No']
# DeviceProtection : ['No' 'Yes']
# TechSupport : ['No' 'Yes']
# StreamingTV : ['No' 'Yes']
# StreamingMovies : ['No' 'Yes']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']
# C:\Users\My Book\anaconda3\lib\site-packages\pandas\core\frame.py:4524: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
print_column_values(ds_altered_totalcharges)
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes']
# OnlineBackup : ['Yes' 'No']
# DeviceProtection : ['No' 'Yes']
# TechSupport : ['No' 'Yes']
# StreamingTV : ['No' 'Yes']
# StreamingMovies : ['No' 'Yes']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection',
                 'TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']

for col in yes_no_columns:
    ds_altered_totalcharges[col].replace({'Yes': 1,'No': 0},inplace = True )
# Out:
# C:\Users\My Book\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
print_column_values(ds_altered_totalcharges)
# Out:
# gender : ['Female' 'Male']
# InternetService : ['DSL' 'Fiber optic' 'No']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']

# %%
ds_altered_totalcharges['gender'].replace({'Female': 1,'Male': 0},inplace = True )

# %%
print_column_values(ds_altered_totalcharges)
# Out:
# InternetService : ['DSL' 'Fiber optic' 'No']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']

# %%
ds_altered_dummies = pd.get_dummies(data = ds_altered_totalcharges, columns = ['InternetService','Contract','PaymentMethod'])

ds_altered_dummies.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
ds_altered_dummies.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# ...

# %%
ds_altered_dummies.head(5)
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       1              0        1           0       1             0
# 1       0              0        0           0      34             1
# 2       0              0        0           0       2             1
# 3       0              0        0           0      45             0
# 4       1              0        0           0       2             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 0              0               0             1                 0  ...
# 1              0               1             0                 1  ...
# 2              0               1             1                 0  ...
# 3              0               1             0                 1  ...
# 4              0               0             0                 0  ...
#
#    InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# ...

# %%
ds_altered_dummies['MonthlyCharges'].head()
# Out:
# 0    29.85
# 1    56.95
# 2    53.85
# 3    42.30
# 4    70.70
# Name: MonthlyCharges, dtype: float64

# %%
ds_altered_dummies[['tenure','MonthlyCharges','TotalCharges']]
# Out:
#       tenure  MonthlyCharges  TotalCharges
# 0          1           29.85         29.85
# 1         34           56.95       1889.50
# 2          2           53.85        108.15
# 3         45           42.30       1840.75
# 4          2           70.70        151.65
# ...      ...             ...           ...
# 7038      24           84.80       1990.50
# 7039      72          103.20       7362.90
# 7040      11           29.60        346.45
# 7041       4           74.40        306.60
# 7042      66          105.65       6844.50
#
# [7032 rows x 3 columns]

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()


ds_altered_dummies[cols_to_scale] = scaler.fit_transform(ds_altered_dummies[cols_to_scale])

# %%
ds_altered_dummies[cols_to_scale]
# Out:
#         tenure  MonthlyCharges  TotalCharges
# 0     0.000000        0.115423      0.001275
# 1     0.464789        0.385075      0.215867
# 2     0.014085        0.354229      0.010310
# 3     0.619718        0.239303      0.210241
# 4     0.014085        0.521891      0.015330
# ...        ...             ...           ...
# 7038  0.323944        0.662189      0.227521
# 7039  1.000000        0.845274      0.847461
# 7040  0.140845        0.112935      0.037809
# 7041  0.042254        0.558706      0.033210
# 7042  0.915493        0.869652      0.787641
#
# [7032 rows x 3 columns]

# %%
ds_altered_dummies.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0       1              0        1           0  0.000000             0
# 1       0              0        0           0  0.464789             1
# 2       0              0        0           0  0.014085             1
# 3       0              0        0           0  0.619718             0
# 4       1              0        0           0  0.014085             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 0              0               0             1                 0  ...
# 1              0               1             0                 1  ...
# 2              0               1             1                 0  ...
# 3              0               1             0                 1  ...
# 4              0               0             0                 0  ...
#
#    InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# ...

# %%
x = ds_altered_dummies.drop('Churn', axis='columns')
y = ds_altered_dummies['Churn']

x.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0       1              0        1           0  0.000000             0
# 1       0              0        0           0  0.464789             1
# 2       0              0        0           0  0.014085             1
# 3       0              0        0           0  0.619718             0
# 4       1              0        0           0  0.014085             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 0              0               0             1                 0  ...
# 1              0               1             0                 1  ...
# 2              0               1             1                 0  ...
# 3              0               1             0                 1  ...
# 4              0               0             0                 0  ...
#
#    InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 , random_state = 5, stratify = y)

X_train.shape
# Out:
# (5625, 26)

# %% [markdown]
# X_test.shape

# %%
y_train.shape,y_test.shape
# Out:
# ((5625,), (1407,))

# %%
y_train.value_counts()
# Out:
# 0    4130
# 1    1495
# Name: Churn, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    1033
# 1     374
# Name: Churn, dtype: int64

# %%
import numpy as np

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import confusion_matrix , classification_report

# %%
def ANN(X_train, y_train, X_test, y_test, loss, weights):
    model = keras.Sequential([
        keras.layers.Dense(26, input_dim=26, activation='relu'),
        keras.layers.Dense(15, activation='relu'),
        keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    
    if weights == -1:
        model.fit(X_train, y_train, epochs=50)
    else:
        model.fit(X_train, y_train, epochs=50, class_weight = weights)
    
    print(model.evaluate(X_test, y_test))
    
    y_preds = model.predict(X_test)
    y_preds = np.round(y_preds)
    
    print("Classification Report: \n", classification_report(y_test, y_preds))
    
    return y_preds

# %% [markdown]
# ## No Sampling

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 176/176 [==============================] - 5s 6ms/step - loss: 0.5545 - accuracy: 0.6885
# Epoch 2/50
# 176/176 [==============================] - 1s 6ms/step - loss: 0.4358 - accuracy: 0.7938
# Epoch 3/50
# 176/176 [==============================] - 1s 6ms/step - loss: 0.4267 - accuracy: 0.7984
# Epoch 4/50
# 176/176 [==============================] - 1s 6ms/step - loss: 0.4244 - accuracy: 0.8004
# Epoch 5/50
# 176/176 [==============================] - 1s 6ms/step - loss: 0.4200 - accuracy: 0.8044
# Epoch 6/50
# 176/176 [==============================] - 1s 6ms/step - loss: 0.4180 - accuracy: 0.8055
# Epoch 7/50
# 176/176 [==============================] - 1s 6ms/step - loss: 0.4169 - accuracy: 0.8039
# Epoch 8/50
# 176/176 [==============================] - 1s 6ms/step - loss: 0.4154 - accuracy: 0.8043
# Epoch 9/50
# 176/176 [==============================] - 1s 6ms/step - loss: 0.4127 - accuracy: 0.8085
# Epoch 10/50
# ...

# %%
#from sklearn.model_selection import StratifiedKFold

#x_stratifiedfold = ds_altered_dummies.drop('Churn', axis='columns')
#y_stratifiedfold = ds_altered_dummies['Churn']

#skf = StratifiedKFold(n_splits=5)
#print(skf.get_n_splits(x_stratifiedfold, y_stratifiedfold))

#for train_index, test_index in skf.split(x_stratifiedfold, y_stratifiedfold):
    #print("TRAIN:", train_index, "TEST:", test_index)
 #   X_train, X_test = x_stratifiedfold.iloc[list(train_index)], x_stratifiedfold.iloc[list(test_index)]
 #   y_train, y_test = y_stratifiedfold.iloc[list(train_index)], y_stratifiedfold.iloc[list(test_index)]

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (5625, 26)
# (5625,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (1407, 26)
# (1407,)

# %%
train_data = pd.concat([X_train,y_train],axis = 'columns')
train_data.head()
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5795       0              0        0           0  0.535211             1
# 1175       1              0        0           0  0.169014             1
# 6631       0              0        1           0  0.338028             1
# 3157       0              0        0           0  0.112676             1
# 6881       1              0        1           1  0.436620             0
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5795              1               1             1                 0  ...
# 1175              1               1             0                 0  ...
# 6631              1               0             0                 1  ...
# 3157              0               0             0                 0  ...
# 6881              0               1             1                 0  ...
#
#       InternetService_Fiber optic  InternetService_No  \
# ...

# %%
class_0_count,class_1_count = train_data.Churn.value_counts()
class_0_count,class_1_count
# Out:
# (4130, 1495)

# %%
train_data_class0 = train_data[train_data["Churn"] == 0]
train_data_class1 = train_data[train_data["Churn"] == 1]
train_data_class0.shape,train_data_class1.shape
# Out:
# ((4130, 27), (1495, 27))

# %% [markdown]
# ## Method 1 : Undersampling

# %%
train_data_under_class0_sampled = train_data_class0.sample(class_1_count)
train_data_under_class0_sampled.shape
# Out:
# (1495, 27)

# %%
train_data_under_sampled = pd.concat([train_data_under_class0_sampled,train_data_class1],axis=0)
train_data_under_sampled.shape
# Out:
# (2990, 27)

# %%
print("Random Undersampling :")
print(train_data_under_sampled.Churn.value_counts())
# Out:
# Random Undersampling :
# 0    1495
# 1    1495
# Name: Churn, dtype: int64

# %%
x_train_sampled = train_data_under_sampled.drop('Churn', axis='columns')
y_train_sampled = train_data_under_sampled['Churn']

x_train_sampled.shape,y_train_sampled.shape
# Out:
# ((2990, 26), (2990,))

# %%
X_test.shape,y_test.shape
# Out:
# ((1407, 26), (1407,))

# %%
y_train_sampled.value_counts()
# Out:
# 0    1495
# 1    1495
# Name: Churn, dtype: int64

# %%
y_preds = ANN(x_train_sampled, y_train_sampled, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 94/94 [==============================] - 3s 6ms/step - loss: 0.5934 - accuracy: 0.7100
# Epoch 2/50
# 94/94 [==============================] - 1s 6ms/step - loss: 0.5203 - accuracy: 0.7492
# Epoch 3/50
# 94/94 [==============================] - 1s 6ms/step - loss: 0.5032 - accuracy: 0.7535
# Epoch 4/50
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4952 - accuracy: 0.7575
# Epoch 5/50
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4900 - accuracy: 0.7599
# Epoch 6/50
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4868 - accuracy: 0.7642
# Epoch 7/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4862 - accuracy: 0.7579
# Epoch 8/50
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4824 - accuracy: 0.7615
# Epoch 9/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4815 - accuracy: 0.7622
# Epoch 10/50
# ...

# %% [markdown]
# ## Method 2 : Over Sampling

# %%
train_data_over_class1_sampled = train_data_class1.sample(class_0_count,replace=True)
train_data_over_class1_sampled.shape
# Out:
# (4130, 27)

# %%
train_data_class0.shape
# Out:
# (4130, 27)

# %%
train_data_over_sampled = pd.concat([train_data_class0,train_data_over_class1_sampled],axis=0)
train_data_over_sampled.shape
# Out:
# (8260, 27)

# %%
print("Random Oversampling :")
print(train_data_over_sampled.Churn.value_counts())
# Out:
# Random Oversampling :
# 0    4130
# 1    4130
# Name: Churn, dtype: int64

# %%
x_train_over_sampled = train_data_over_sampled.drop('Churn', axis='columns')
y_train_over_sampled = train_data_over_sampled['Churn']

x_train_over_sampled.shape,y_train_over_sampled.shape
# Out:
# ((8260, 26), (8260,))

# %%
y_preds_over = ANN(x_train_over_sampled, y_train_over_sampled, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 259/259 [==============================] - 3s 5ms/step - loss: 0.5528 - accuracy: 0.7260
# Epoch 2/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4935 - accuracy: 0.7653
# Epoch 3/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4867 - accuracy: 0.7667
# Epoch 4/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4819 - accuracy: 0.7656
# Epoch 5/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4771 - accuracy: 0.7677
# Epoch 6/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4744 - accuracy: 0.7689
# Epoch 7/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4714 - accuracy: 0.7725
# Epoch 8/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4689 - accuracy: 0.7697
# Epoch 9/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4671 - accuracy: 0.7731
# Epoch 10/50
# ...

# %% [markdown]
# ## Method 3 : SMOTE

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy = 'minority')
x_sm,y_sm = smote.fit_resample(X_train,y_train)

y_sm.value_counts()
# Out:
# 0    4130
# 1    4130
# Name: Churn, dtype: int64

# %%
y_preds_over = ANN(x_sm, y_sm, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 259/259 [==============================] - 3s 5ms/step - loss: 0.5350 - accuracy: 0.7349
# Epoch 2/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4769 - accuracy: 0.7725
# Epoch 3/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4662 - accuracy: 0.7810
# Epoch 4/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4596 - accuracy: 0.7818
# Epoch 5/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4532 - accuracy: 0.7846
# Epoch 6/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4489 - accuracy: 0.7845
# Epoch 7/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4441 - accuracy: 0.7913
# Epoch 8/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4407 - accuracy: 0.7907
# Epoch 9/50
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4380 - accuracy: 0.7904
# Epoch 10/50
# ...

# %% [markdown]
# ## Method 4 : Ensemble

# %%
def get_ensemble_batch(df_majority,df_minority,start,end):
    y_train_ensemble = pd.concat([df_majority[start:end],df_minority],axis=0)
    x_train = y_train_ensemble.drop('Churn', axis='columns')
    y_train = y_train_ensemble['Churn']
    
    return x_train,y_train

# %%
X_train,y_train = get_ensemble_batch(train_data_class0,train_data_class1,0,1495)
y_preds1 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 94/94 [==============================] - 2s 5ms/step - loss: 0.6236 - accuracy: 0.6659
# Epoch 2/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5319 - accuracy: 0.7431
# Epoch 3/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5150 - accuracy: 0.7475
# Epoch 4/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5085 - accuracy: 0.7465
# Epoch 5/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5036 - accuracy: 0.7472
# Epoch 6/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4991 - accuracy: 0.7545
# Epoch 7/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4970 - accuracy: 0.7545
# Epoch 8/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4972 - accuracy: 0.7512
# Epoch 9/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4918 - accuracy: 0.7565
# Epoch 10/50
# ...

# %%
X_train,y_train = get_ensemble_batch(train_data_class0,train_data_class1,1495,2990)
y_preds2 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 94/94 [==============================] - 2s 5ms/step - loss: 0.5918 - accuracy: 0.7037
# Epoch 2/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5109 - accuracy: 0.7622
# Epoch 3/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4958 - accuracy: 0.7649
# Epoch 4/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4911 - accuracy: 0.7659
# Epoch 5/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4862 - accuracy: 0.7706
# Epoch 6/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4818 - accuracy: 0.7719
# Epoch 7/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4802 - accuracy: 0.7689
# Epoch 8/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4772 - accuracy: 0.7759
# Epoch 9/50
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4761 - accuracy: 0.7706
# Epoch 10/50
# ...

# %%
X_train,y_train = get_ensemble_batch(train_data_class0,train_data_class1,2990,4130)
y_preds3 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/50
# 83/83 [==============================] - 2s 5ms/step - loss: 0.6069 - accuracy: 0.6884
# Epoch 2/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.5011 - accuracy: 0.7662
# Epoch 3/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4794 - accuracy: 0.7738
# Epoch 4/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4738 - accuracy: 0.7753
# Epoch 5/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4710 - accuracy: 0.7765
# Epoch 6/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4671 - accuracy: 0.7769
# Epoch 7/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4680 - accuracy: 0.7765
# Epoch 8/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4626 - accuracy: 0.7776
# Epoch 9/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4618 - accuracy: 0.7814
# Epoch 10/50
# ...

# %%
y_pred_final = y_preds1.copy()

for i in range(len(y_preds1)):
    n_one = y_preds1[i]+y_preds2[i]+y_preds3[i]
    if n_one>1:
        y_pred_final[i] = 1
    else:
        y_pred_final[i] = 0

# %%
print(classification_report(y_test,y_pred_final))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.82      1033
#            1       0.53      0.81      0.64       374
#
#     accuracy                           0.76      1407
#    macro avg       0.72      0.77      0.73      1407
# weighted avg       0.81      0.76      0.77      1407
